-- %%
-- Fetch any new alerts triggered in the last 5 minutes
SELECT 
    customer_id, 
    amount, 
    dist_from_home_km, 
    event_time
FROM fraud_sentinel_catalog.detection_service.gold_fraud_alerts
WHERE event_time > now() - interval 5 minutes
